# %% [markdown]
# <a href="https://colab.research.google.com/github/maseylan/House-Price-Prediction/blob/main/Insert_edit_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# %%
data_yt = pd.read_csv('/most_subscribed_youtube_channels.csv')
data_yt
# Out:
#      rank                    Youtuber  subscribers      video views  \
# 0       1                    T-Series  222,000,000  198,459,090,822
# 1       2              YouTube Movies  154,000,000                0
# 2       3  Cocomelon - Nursery Rhymes  140,000,000  135,481,339,848
# 3       4                   SET India  139,000,000  125,764,252,686
# 4       5                       Music  116,000,000                0
# ..    ...                         ...          ...              ...
# 995   996                    JP Plays   10,900,000    4,609,300,218
# 996   997               TrapMusicHDTV   10,900,000    4,070,521,973
# 997   998                 Games EduUu   10,900,000    3,093,784,767
# 998   999                       Hueva   10,900,000    3,040,301,750
# 999  1000              Dobre Brothers   10,900,000    2,808,411,693
#
#     video count          category  started
# 0        17,317             Music     2006
# 1             0  Film & Animation     2015
# ...

# %%
data_yt.info()
data_yt.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         1000 non-null   int64
#  1   Youtuber     1000 non-null   object
#  2   subscribers  1000 non-null   object
#  3   video views  1000 non-null   object
#  4   video count  1000 non-null   object
#  5   category     973 non-null    object
#  6   started      1000 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB
#      rank        Youtuber subscribers    video views video count  \
# 995   996        JP Plays  10,900,000  4,609,300,218       3,528
# 996   997   TrapMusicHDTV  10,900,000  4,070,521,973         690
# 997   998     Games EduUu  10,900,000  3,093,784,767       1,006
# 998   999           Hueva  10,900,000  3,040,301,750         831
# 999  1000  Dobre Brothers  10,900,000  2,808,411,693         590
#
#            category  started
# ...

# %%
data_yt.sample(15)

# %%
data_yt['subscribers'] = data_yt['subscribers'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b5b3e1aac50c> in <cell line: 1>()
# ----> 1 data_yt['subscribers'] = data_yt['subscribers'].astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
data_yt.index
data_yt.set_index('category')
# Out:
#                   rank                    Youtuber  subscribers  \
# category
# Music                1                    T-Series  222,000,000
# Film & Animation     2              YouTube Movies  154,000,000
# Education            3  Cocomelon - Nursery Rhymes  140,000,000
# Shows                4                   SET India  139,000,000
# NaN                  5                       Music  116,000,000
# ...                ...                         ...          ...
# Gaming             996                    JP Plays   10,900,000
# Music              997               TrapMusicHDTV   10,900,000
# Gaming             998                 Games EduUu   10,900,000
# Gaming             999                       Hueva   10,900,000
# People & Blogs    1000              Dobre Brothers   10,900,000
#
#                       video views video count  started
# category
# Music             198,459,090,822      17,317     2006
# Film & Animation                0           0     2015
# ...

# %%
data_yt.tail().set_index('Youtuber')
# Out:
#                 rank subscribers video views video count        category  \
# Youtuber
# JP Plays         996  10,900,000  4609300218       3,528          Gaming
# TrapMusicHDTV    997  10,900,000  4070521973         690           Music
# Games EduUu      998  10,900,000  3093784767       1,006          Gaming
# Hueva            999  10,900,000  3040301750         831          Gaming
# Dobre Brothers  1000  10,900,000  2808411693         590  People & Blogs
#
#                 started
# Youtuber
# JP Plays           2014
# TrapMusicHDTV      2013
# Games EduUu        2011
# Hueva              2012
# Dobre Brothers     2017

# %%
data_yt.loc[8]
# Out:
# rank                        9
# Youtuber          Like Nastya
# subscribers        99,200,000
# video views    81,963,845,811
# video count               702
# category       People & Blogs
# started                  2016
# Name: 8, dtype: object

# %%
data_yt.head(8)

# %%
data_yt["category"]
# Out:
# 0                 Music
# 1      Film & Animation
# 2             Education
# 3                 Shows
# 4                   NaN
#              ...
# 995              Gaming
# 996               Music
# 997              Gaming
# 998              Gaming
# 999      People & Blogs
# Name: category, Length: 1000, dtype: object

# %%
data_yt.loc[1:12:,["category","started","subscribers"]]

# %%
data_yt.loc[0:100:,["category","video views","subscribers"]]

# %%
data_yt['video views'] = data_yt['video views'].replace('Unknown','0')

# %%
data_yt['category'] = data_yt['category'].replace('NaN','Undefined')

# %%
data_yt['category'].fillna('Undefined', inplace=True)
data_yt['video views'] = data_yt['video views'].replace('Unknown','0')

# %%
data_yt['video views'] = data_yt['video views'].str.replace(',', '')
data_yt['subscribers'] = data_yt['subscribers'].str.replace(',','')

# %%
data_yt['video count'] = data_yt['video count'].str.replace(',','')

# %%
data_yt.loc[10]
# Out:
# rank                    11
# Youtuber               WWE
# subscribers       90200000
# video views    70544743313
# video count         63,077
# category            Sports
# started               2007
# Name: 10, dtype: object

# %%
data_yt['subscribers'] = data_yt['subscribers'].astype(int)
data_yt['video views'] = pd.to_numeric(data_yt['video views']).astype(int)

# %%
data_yt['video count'] = pd.to_numeric(data_yt['video count']).astype(int)

# %%
data_yt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         1000 non-null   int64
#  1   Youtuber     1000 non-null   object
#  2   subscribers  1000 non-null   int64
#  3   video views  1000 non-null   int64
#  4   video count  1000 non-null   int64
#  5   category     1000 non-null   object
#  6   started      1000 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 54.8+ KB

# %%
data_yt['video views'].dtypes
# Out:
# dtype('int64')

# %%
data_yt['category'].unique()
# Out:
# array(['Music', 'Film & Animation', 'Education', 'Shows', 'Undefined',
#        'Gaming', 'Entertainment', 'People & Blogs', 'Sports',
#        'Howto & Style', 'News & Politics', 'Comedy', 'Trailers',
#        'Nonprofits & Activism', 'Science & Technology', 'Movies',
#        'Pets & Animals', 'Autos & Vehicles', 'Travel & Events'],
#       dtype=object)

# %%
data_yt['category'] == 'Sports'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: category, Length: 1000, dtype: bool

# %%
data_yt[(data_yt["rank"] >= 500) & (data_yt["category"] == "Music")]
# Out:
#      rank           Youtuber  subscribers  video views  video count category  \
# 504   505           FitDance     15400000   6541827030         3537    Music
# 511   512          AdeleVEVO     15200000  11470355227           51    Music
# 512   513             Camilo     15200000   6003697328           80    Music
# 524   525          POPS Kids     15000000   8678492072         4478    Music
# 525   526          SAM SMITH     15000000   8769075543           67    Music
# ..    ...                ...          ...          ...          ...      ...
# 969   970             Genius     11100000   2891052624         2797    Music
# 982   983           Doja Cat     11000000   5459891400           25    Music
# 983   984               Tyga     11000000   5211071220          160    Music
# 989   990  unknown boy varun     11000000   3263285883          193    Music
# 996   997      TrapMusicHDTV     10900000   4070521973          690    Music
#
#      started
# 504     2013
# 511     2009
# ...

# %% [markdown]
# Filter data yang ingin dicari dengan 2 kondisi, peringkat 500 keatas dari jumlah subscriber dengan kategori sports

# %%
low_rank_youtuber_views_and_video_undefined = data_yt[(data_yt["rank"] >= 500) & (data_yt["video count"] == 0) & (data_yt['video views'] >= 0) ]
low_rank_youtuber_views_and_video_undefined
# Out:
#      rank   Youtuber  subscribers  video views  video count          category  \
# 507   508       Live     15300000            0            0         Undefined
# 870   871  Machinima     11700000            0            0  Film & Animation
# 977   978   TV Shows     11000000            0            0         Undefined
#
#      started
# 507     2015
# 870     2006
# 977     2012

# %% [markdown]
# youtuber dengan peringkat subscriber diatas 500 yang video views dan video count nya 0

# %%
youtuber_sport_top50 = data_yt[(data_yt['rank']<=50) & (data_yt['category']== 'Sports')]
youtuber_sport_top50
# Out:
#     rank      Youtuber  subscribers  video views  video count category  \
# 10    11           WWE     90200000  70544743313        63077   Sports
# 25    26  Dude Perfect     58100000  14742860905          297   Sports
#
#     started
# 10     2007
# 25     2009

# %% [markdown]
# youtuber dengan subscireber top 50 dengan kategori siaran Sports

# %%
youtber_music_start_from_2010 = data_yt[(data_yt['started']>= 2010) & (data_yt['category']== 'Music')]
youtber_music_start_from_2010.head(15)

# %%
youtuber_most_video_views = data_yt.sort_values(by="video views",ascending= True)
youtuber_most_video_views.tail(10)
# Out:
#     rank                    Youtuber  subscribers   video views  video count  \
# 29    30                   Colors TV     55100000   52611504230        87427
# 27    28                  Movieclips     57600000   58839819120        39202
# 12    13               Vlad and Niki     85100000   66498762660          472
# 10    11                         WWE     90200000   70544743313        63077
# 7      8           ✿ Kids Diana Show     99700000   79602288245         1009
# 8      9                 Like Nastya     99200000   81963845811          702
# 17    18                    Sony SAB     70600000   82473581441        56295
# 3      4                   SET India    139000000  125764252686        91271
# 2      3  Cocomelon - Nursery Rhymes    140000000  135481339848          786
# 0      1                    T-Series    222000000  198459090822        17317
#
#             category  started
# 29             Shows     2008
# 27  Film & Animation     2006
# ...

# %% [markdown]
# Menggunakan fitur sorting dengan ascending

# %%
youtuber_most_video_views.duplicated().sum()
# Out:
# 0

# %%
data_yt['category'].isna().sum()
data_yt{'category'}.fillna('other')
# Out:
# 0

# %% [markdown]
# menjumlah total NaN pada column

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-b57feb38ecbb> in <cell line: 1>()
# ----> 1 data_yt["category"].fillundefined("Others")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'fillundefined'
